# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/radhika456/Prepinsta-Winter-Internship---Data-Analytics/master/Week%233/chipotle.tsv",sep='\t')
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
df.isnull().sum()
# Out:
# order_id                 0
# quantity                 0
# item_name                0
# choice_description    1246
# item_price               0
# dtype: int64

# %%
#Finding and deleting the duplicates
print(df.duplicated().sum())
print(df.drop_duplicates())
print('\n')
print(df)
# Out:
# 59
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#Reassigning the result of applying the drop_duplicates() method to a new variable:
df_no_duplicates = df.drop_duplicates()
print(df_no_duplicates)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
#Modifying the current dataframe in place after removing duplicates from it:
df.drop_duplicates(inplace=True)
print(df)
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# ...

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# 3                                                NaN     $2.39
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98

# %%
#Removing square brackets
def concatenate_choices(choices):
    if pd.notna(choices):
        # Remove square brackets and quotes, if present
        choices = choices.replace('[', '').replace(']', '').replace("'", "")
        # Split the choices and join them with a comma
        choices_list = choices.split(', ')
        return ', '.join(choices_list)
    else:
        return None

# Apply the function to the 'choice_description' column
df['choice_description'] = df['choice_description'].apply(concatenate_choices)

# Display the modified DataFrame
print(df[['order_id', 'item_name', 'choice_description']])
# Out:
#       order_id                              item_name  \
# 0            1           Chips and Fresh Tomato Salsa
# 1            1                                   Izze
# 2            1                       Nantucket Nectar
# 3            1  Chips and Tomatillo-Green Chili Salsa
# 4            2                           Chicken Bowl
# ...        ...                                    ...
# 4617      1833                          Steak Burrito
# 4618      1833                          Steak Burrito
# 4619      1834                     Chicken Salad Bowl
# 4620      1834                     Chicken Salad Bowl
# 4621      1834                     Chicken Salad Bowl
#
#                                      choice_description
# 0                                                  None
# 1                                            Clementine
# 2                                                 Apple
# 3                                                  None
# ...

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price
# 0                                               None     $2.39
# 1                                         Clementine     $3.39
# 2                                              Apple     $3.39
# 3                                               None     $2.39
# 4  Tomatillo-Red Chili Salsa (Hot), Black Beans, ...    $16.98

# %%
# Function to extract individual choices
def extract_choices(choices, choice_number):
    if pd.notna(choices):
        # Remove square brackets and quotes, if present
       # choices = choices.replace('[', '').replace(']', '').replace("'", "")
        # Split the choices and return the choice at the specified index
        choices_list = choices.split(', ')
        return choices_list[choice_number] if choice_number < len(choices_list) else None
    else:
        return None

# Define the maximum number of choices you want to extract
max_choices = 5

# Create new columns for each choice
for i in range(max_choices):
    df[f'choice_{i+1}'] = df['choice_description'].apply(lambda x: extract_choices(x, i))

# Display the modified DataFrame
print(df[['order_id', 'item_name', 'choice_description', 'choice_1', 'choice_2', 'choice_3', 'choice_4', 'choice_5']])
# Out:
#       order_id                              item_name  \
# 0            1           Chips and Fresh Tomato Salsa
# 1            1                                   Izze
# 2            1                       Nantucket Nectar
# 3            1  Chips and Tomatillo-Green Chili Salsa
# 4            2                           Chicken Bowl
# ...        ...                                    ...
# 4617      1833                          Steak Burrito
# 4618      1833                          Steak Burrito
# 4619      1834                     Chicken Salad Bowl
# 4620      1834                     Chicken Salad Bowl
# 4621      1834                     Chicken Salad Bowl
#
#                                      choice_description  \
# 0                                                  None
# 1                                            Clementine
# 2                                                 Apple
# 3                                                  None
# ...

# %%
df.head(5)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
#
#                                   choice_description item_price  \
# 0                                               None     $2.39
# 1                                         Clementine     $3.39
# 2                                              Apple     $3.39
# 3                                               None     $2.39
# 4  Tomatillo-Red Chili Salsa (Hot), Black Beans, ...    $16.98
#
#                           choice_1     choice_2 choice_3 choice_4    choice_5
# 0                             None         None     None     None        None
# ...

# %%
csv_file_path = 'cleaned_dataset_2.csv'

# Convert the DataFrame to a CSV file
df.to_csv('/content/sample_data/cleaned_dataset_2.csv', sep=',', index=False)

print(f'The cleaned dataset has been successfully saved to {csv_file_path}.')
# Out:
# The cleaned dataset has been successfully saved to cleaned_dataset_2.csv.
